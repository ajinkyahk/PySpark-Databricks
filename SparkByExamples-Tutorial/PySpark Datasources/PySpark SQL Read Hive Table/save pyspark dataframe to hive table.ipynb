# %% [markdown]
# #save pyspark dataframe to hive table

# %%
spark.conf.get("spark.sql.warehouse.dir")
# Out:
# Out[1]: 'dbfs:/user/hive/warehouse'

# %%
columns = ["id", "name", "age", "gender"]

#create DataFrame
data = [(1, "James",30,"M"), (2, "Ann",40,"F"),
    (3, "Jeff",41,"M"),(4, "Jennifer",20,"F")]

sampleDF = sc.parallelize(data).toDF(columns)

# %%
#Create a temporary view
sampleDF.createOrReplaceTempView("sampleView")

# %%
spark.sql(" DROP DATABASE ct")
#Create a database CT
spark.sql("CREATE DATABASE IF NOT EXISTS ct")
# Out:
# Out[11]: DataFrame[]

# %%
#Create a Table naming as sampleTable under CT database

spark.sql(" CREATE TABLE ct.sampleTable (id Int, name String, age Int, gender String )")
# Out:
# Out[12]: DataFrame[]

# %%
#Insert into sampleTable using the sampleView
spark.sql("INSERT INTO TABLE ct.sampleTable SELECT * FROM sampleView")
# Out:
# Out[13]: DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
#Lets view the data in the table 
spark.sql("SELECT * FROM ct.sampleTable").show(truncate=False)
# Out:
# +---+--------+---+------+
# |id |name    |age|gender|
# +---+--------+---+------+
# |4  |Jennifer|20 |F     |
# |1  |James   |30 |M     |
# |3  |Jeff    |41 |M     |
# |2  |Ann     |40 |F     |
# +---+--------+---+------+

# %%
# %sql DESCRIBE TABLE EXTENDED ct.sampleTable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>name</td><td>string</td><td>null</td></tr><tr><td>age</td><td>int</td><td>null</td></tr><tr><td>gender</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>ct</td><td></td></tr><tr><td>Table</td><td>sampleTable</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/ct.db/sampletable</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>
