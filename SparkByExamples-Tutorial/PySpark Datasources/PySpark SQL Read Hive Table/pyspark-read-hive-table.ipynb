# %% [markdown]
# #pyspark-read-hive-table

# %%
#Read hive table using table
df = spark.read.table("ct.sampleTable")
df.show()
# Out:
# +---+--------+---+------+
# | id|    name|age|gender|
# +---+--------+---+------+
# |  4|Jennifer| 20|     F|
# |  1|   James| 30|     M|
# |  3|    Jeff| 41|     M|
# |  2|     Ann| 40|     F|
# +---+--------+---+------+

# %%
df2 = spark.sql(" SELECT * FROM ct.sampleTable")
df2.show()
# Out:
# +---+--------+---+------+
# | id|    name|age|gender|
# +---+--------+---+------+
# |  4|Jennifer| 20|     F|
# |  1|   James| 30|     M|
# |  3|    Jeff| 41|     M|
# |  2|     Ann| 40|     F|
# +---+--------+---+------+
