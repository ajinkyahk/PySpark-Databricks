# %%
dbutils.widgets.text("Filename", '')

# %%
filename = dbutils.widgets.get('Filename')
print(filename)
# Out:
# part-00000.snappy.parquet

# %%
dbutils.fs.mount(

  source = "wasbs://data@akitvretail.blob.core.windows.net",

  mount_point = "/mnt/mydata",

  extra_configs = {"fs.azure.account.key.akitvretail.blob.core.windows.net": ''})
# Out:
# True

# %%
df = spark.read.parquet(f"/mnt/mydata/retail_db_parquet/orders/{filename}")

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.widgets.removeAll()

# %%
dbutils.fs.unmount("/mnt/mydata")
# Out:
# /mnt/mydata has been unmounted.
# True

# %%
dbutils.notebook.exit(f"This file read:- {filename}")
